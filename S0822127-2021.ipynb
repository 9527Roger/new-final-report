# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px

# %%
rowdata = pd.read_csv('./unilions2021.csv')
rowdata.head(10)
# Out:
#         date  no.24     no.64     no.77     no.32  no.39     no.31  no.13  \
# 0  2021/3/13   0.50  0.000000  0.800000  0.500000    0.5  2.000000   0.25
# 1  2021/3/14   0.50  0.500000  0.500000  0.500000    0.0  0.666667   0.00
# 2  2021/3/16   0.65  0.000000  2.083333  0.750000    0.0  0.000000   0.00
# 3  2021/3/17   0.50  0.000000  0.250000  1.583333    0.0  0.666667   0.00
# 4  2021/3/18   0.50  0.000000  0.833333  0.500000    0.0  0.000000   0.00
# 5  2021/3/20   0.00  0.500000  5.000000  0.000000    0.0  0.000000   0.00
# 6  2021/3/21   0.00  0.666667  0.500000  1.000000    0.0  1.000000   0.00
# 7  2021/3/25   0.40  0.666667  0.650000  0.000000    0.0  0.000000   0.00
# 8  2021/3/27   0.00  0.666667  0.000000  1.833333    0.0  0.000000   0.00
# 9  2021/3/30   0.00  0.000000  0.250000  0.500000    0.0  0.000000   0.00
#
#        no.5  no.2     no.66  match
# 0  1.200000  0.00  0.000000      0
# 1  1.166667  0.00  0.000000      1
# 2  1.250000  0.00  0.500000      0
# ...

# %%
rowdata['match'].value_counts()
# Out:
# 0    128
# 1    112
# Name: match, dtype: int64

# %%
num_cols = [col for col in rowdata.columns if rowdata[col].dtypes !='object']

# %%
plt.figure(figsize =(20,10))
plot_number = 1
for column in num_cols:
    if plot_number <= 10:
        ax = plt.subplot(3, 5, plot_number)
        sns.distplot(rowdata[column])
        plt.xlabel(column)

    plot_number += 1
plt.tight_layout()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12592\1692447605.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(rowdata[column])
# C:\Users\USER\AppData\Local\Temp\ipykernel_12592\1692447605.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(rowdata[column])
# ...

# %%
#繪製小提琴圖形，以發生可能為x軸,y軸為想了解球員打擊表現跟球隊勝利發生相關的數據
def violin(col):
    fig = px.violin(rowdata, y=col, x="match", color="match", box=True, template = 'plotly_dark')
    return fig.show()
#繪製兩條曲線圖，以x軸為想了解球員打擊表現跟球隊勝利相關的數據,y軸為發生密度，兩條曲線一條為發生的曲線，另一條為不發生的曲線
def kde(col):
    grid = sns.FacetGrid(rowdata, hue="match", height = 6, aspect=2)
    grid.map(sns.kdeplot,col)
    grid.add_legend()

# %%
#由圖形可以得知，體內的葡萄糖含量、年紀、BMI是最有可能去引發糖尿病發的狀況。
violin('no.24')
violin('no.64')
violin('no.77')
violin('no.32')
violin('no.39')
violin('no.31')
violin('no.13')
violin('no.5')
violin('no.2')
violin('no.66')

# %%
kde('no.24')
kde('no.64')
kde('no.77')
kde('no.32')
kde('no.39')
kde('no.31')
kde('no.13')
kde('no.5')
kde('no.2')
kde('no.66')

# %%
clear_data1 = rowdata.drop(['date'],axis=1)
clear_data =clear_data1.drop(['match'],axis=1)
label = rowdata['match']

# %%
clear_data
# Out:
#         no.24     no.64     no.77     no.32  no.39     no.31  no.13      no.5  \
# 0    0.500000  0.000000  0.800000  0.500000    0.5  2.000000   0.25  1.200000
# 1    0.500000  0.500000  0.500000  0.500000    0.0  0.666667   0.00  1.166667
# 2    0.650000  0.000000  2.083333  0.750000    0.0  0.000000   0.00  1.250000
# 3    0.500000  0.000000  0.250000  1.583333    0.0  0.666667   0.00  0.750000
# 4    0.500000  0.000000  0.833333  0.500000    0.0  0.000000   0.00  1.250000
# ..        ...       ...       ...       ...    ...       ...    ...       ...
# 235  0.500000  0.000000  0.666667  0.000000    0.0  0.000000   0.00  1.000000
# 236  0.833333  1.750000  0.000000  0.000000    0.0  0.000000   0.00  1.250000
# 237  0.250000  0.500000  0.000000  0.000000    0.0  0.000000   0.00  0.000000
# 238  0.533333  1.633333  0.000000  0.000000    0.0  0.000000   0.00  0.666667
# 239  0.000000  0.500000  0.000000  0.000000    0.0  0.000000   0.00  0.000000
#
#      no.2     no.66
# ...

# %%
x_features = clear_data
y_label = label
x_features
# Out:
#         no.24     no.64     no.77     no.32  no.39     no.31  no.13      no.5  \
# 0    0.500000  0.000000  0.800000  0.500000    0.5  2.000000   0.25  1.200000
# 1    0.500000  0.500000  0.500000  0.500000    0.0  0.666667   0.00  1.166667
# 2    0.650000  0.000000  2.083333  0.750000    0.0  0.000000   0.00  1.250000
# 3    0.500000  0.000000  0.250000  1.583333    0.0  0.666667   0.00  0.750000
# 4    0.500000  0.000000  0.833333  0.500000    0.0  0.000000   0.00  1.250000
# ..        ...       ...       ...       ...    ...       ...    ...       ...
# 235  0.500000  0.000000  0.666667  0.000000    0.0  0.000000   0.00  1.000000
# 236  0.833333  1.750000  0.000000  0.000000    0.0  0.000000   0.00  1.250000
# 237  0.250000  0.500000  0.000000  0.000000    0.0  0.000000   0.00  0.000000
# 238  0.533333  1.633333  0.000000  0.000000    0.0  0.000000   0.00  0.666667
# 239  0.000000  0.500000  0.000000  0.000000    0.0  0.000000   0.00  0.000000
#
#      no.2     no.66
# ...

# %% [markdown]
# Bagging去討論選手與勝負的重要性

# %%
from sklearn.model_selection import train_test_split # 拆分資料集
from sklearn.model_selection import train_test_split
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score
X = clear_data
y = label

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
dt = BaggingClassifier(DecisionTreeClassifier()) # 只使用一棵決策樹
dt.fit(X_train, y_train) # 擬合模型
y_pred = dt.predict(X_test) # 進行預測

# 取得第一個決策樹的特徵重要性
feature_importances = dt.estimators_[0].feature_importances_
selected_feature_names = clear_data.columns.tolist()

# 顯示每個特徵的重要性
for feature_name, importance in zip(selected_feature_names, feature_importances):
    print("特徵名稱: {}, 重要性: {:.4f}".format(feature_name, importance))

# 顯示結果
print("决策樹測試準確率: {:.2f}%".format(dt.score(X_test, y_test) * 100))
print("决策樹測試F1 score: {:.2f}%".format(f1_score(y_test, y_pred) * 100))

print('----------------------------------------------------------')
bdt = BaggingClassifier(DecisionTreeClassifier()) # 樹的Bagging
bdt.fit(X_train, y_train) # 擬合模型
y_pred = bdt.predict(X_test) # 進行預測

# 取得第一個決策樹的特徵重要性
feature_importances = bdt.estimators_[0].feature_importances_

# 顯示每個特徵的重要性
for feature_name, importance in zip(selected_feature_names, feature_importances):
    print("特徵名稱: {}, 重要性: {:.4f}".format(feature_name, importance))

# 顯示結果
print("决策樹Bagging測試準確率: {:.2f}%".format(bdt.score(X_test, y_test) * 100))
print("决策樹Bagging測試F1 score: {:.2f}%".format(f1_score(y_test, y_pred) * 100))
# Out:
# 特徵名稱: no.24, 重要性: 0.3346
# 特徵名稱: no.64, 重要性: 0.0491
# 特徵名稱: no.77, 重要性: 0.1027
# 特徵名稱: no.32, 重要性: 0.0765
# 特徵名稱: no.39, 重要性: 0.0460
# 特徵名稱: no.31, 重要性: 0.1447
# 特徵名稱: no.13, 重要性: 0.0324
# 特徵名稱: no.5, 重要性: 0.0417
# 特徵名稱: no.2, 重要性: 0.1169
# 特徵名稱: no.66, 重要性: 0.0555
# 决策樹測試準確率: 45.83%
# 决策樹測試F1 score: 38.10%
# ----------------------------------------------------------
# 特徵名稱: no.24, 重要性: 0.2203
# 特徵名稱: no.64, 重要性: 0.1493
# 特徵名稱: no.77, 重要性: 0.0832
# 特徵名稱: no.32, 重要性: 0.0498
# 特徵名稱: no.39, 重要性: 0.0186
# 特徵名稱: no.31, 重要性: 0.1476
# 特徵名稱: no.13, 重要性: 0.0169
# 特徵名稱: no.5, 重要性: 0.0920
# 特徵名稱: no.2, 重要性: 0.0802
# 特徵名稱: no.66, 重要性: 0.1420
# 决策樹Bagging測試準確率: 45.83%
# 决策樹Bagging測試F1 score: 35.00%

# %% [markdown]
# Boosting選手與勝負的關係

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostClassifier # 導入AdaBoost
dt = DecisionTreeClassifier() # 選擇決策樹作為AdaBoost的基礎模型
ada = AdaBoostClassifier(dt) # AdaBoost模型
# 使用網格搜索搜尋最佳化參數
ada_param_grid = {
"n_estimators" :[1,2,5,10],
"learning_rate": [0.0001, 0.001, 0.01, 0.1, 0.2, 0.3,1.5]}
ada_gs = GridSearchCV(ada,param_grid = ada_param_grid,scoring="f1", n_jobs= 10, verbose = 1)
ada_gs.fit(X_train,y_train) # 擬合模型
ada_gs = ada_gs.best_estimator_ # 最佳模型
y_pred = ada_gs.predict(X_test) # 預測
print("Adaboost測試準確率: {:.2f}%".format(ada_gs.score(X_test, y_test)*100))
print("Adaboost測試F1 score: {:.2f}%".format(f1_score(y_test, y_pred)*100))
# Out:
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# Adaboost測試準確率: 52.08%
# Adaboost測試F1 score: 48.89%

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score

# 建立 AdaBoost 模型
dt = DecisionTreeClassifier()  # 選擇決策樹作為 AdaBoost 的基礎模型
ada = AdaBoostClassifier(dt)  # AdaBoost 模型

# 迭代處理每個特徵
for feature_index, feature_name in enumerate(clear_data.columns[0:]):
    X_single_feature = clear_data[[feature_name]].values  # 提取單個特徵作為二維數組
    ada.fit(X_single_feature, y)  # 訓練 AdaBoost 模型
    y_pred = ada.predict(X_single_feature)  # 預測目標變量

    # 輸出結果
    print("特徵名稱: ", feature_name)
    print("Adaboost 訓練準確率: {:.2f}%".format(ada.score(X_single_feature, y) * 100))
    print("Adaboost 訓練 F1 score: {:.2f}%".format(f1_score(y, y_pred) * 100))
    print()
# Out:
# 特徵名稱:  no.24
# Adaboost 訓練準確率: 66.67%
# Adaboost 訓練 F1 score: 55.56%
#
# 特徵名稱:  no.64
# Adaboost 訓練準確率: 68.33%
# Adaboost 訓練 F1 score: 62.75%
#
# 特徵名稱:  no.77
# Adaboost 訓練準確率: 67.08%
# Adaboost 訓練 F1 score: 57.30%
#
# 特徵名稱:  no.32
# Adaboost 訓練準確率: 63.75%
# Adaboost 訓練 F1 score: 51.93%
#
# 特徵名稱:  no.39
# Adaboost 訓練準確率: 57.50%
# Adaboost 訓練 F1 score: 32.89%
#
# 特徵名稱:  no.31
# Adaboost 訓練準確率: 64.17%
# Adaboost 訓練 F1 score: 56.57%
#
# 特徵名稱:  no.13
# Adaboost 訓練準確率: 62.92%
# Adaboost 訓練 F1 score: 40.27%
#
# 特徵名稱:  no.5
# Adaboost 訓練準確率: 63.33%
# Adaboost 訓練 F1 score: 44.30%
#
# 特徵名稱:  no.2
# Adaboost 訓練準確率: 62.50%
# Adaboost 訓練 F1 score: 50.55%
#
# 特徵名稱:  no.66
# Adaboost 訓練準確率: 61.67%
# Adaboost 訓練 F1 score: 43.90%
